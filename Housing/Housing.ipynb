# %%
import pandas as pd

# %%
df = pd.read_csv("NY-House-Dataset.csv")
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
df["TYPE"] = df["TYPE"].str.split(" ").str[0]
df["TYPE"]
# Out:
# 0           Condo
# 1           Condo
# 2           House
# 3           Condo
# 4       Townhouse
#           ...
# 4796        Co-op
# 4797        Co-op
# 4798        Co-op
# 4799        Condo
# 4800        Co-op
# Name: TYPE, Length: 4801, dtype: object

# %%
df["BROKERTITLE"] = df["BROKERTITLE"].str.split(' ').str[2:].str.join(" ")
df
# Out:
#                                             BROKERTITLE       TYPE      PRICE  \
# 0                       Douglas Elliman  -111 Fifth Ave      Condo     315000
# 1                                               Serhant      Condo  195000000
# 2                                            Sowae Corp      House     260000
# 3                                               COMPASS      Condo      69000
# 4     Sotheby's International Realty - East Side Man...  Townhouse   55000000
# ...                                                 ...        ...        ...
# 4796                                            COMPASS      Co-op     599000
# 4797                                Mjr Real Estate Llc      Co-op     245000
# 4798                  Douglas Elliman - 575 Madison Ave      Co-op    1275000
# 4799                        E Realty International Corp      Condo     598125
# 4800                             Nyc Realty Brokers Llc      Co-op     349000
#
# ...

# %%
df["PINCODE"] = df["STATE"].str.split(' ').str[-1]

# %%
df.head()
# Out:
#                                          BROKERTITLE       TYPE      PRICE  \
# 0                    Douglas Elliman  -111 Fifth Ave      Condo     315000
# 1                                            Serhant      Condo  195000000
# 2                                         Sowae Corp      House     260000
# 3                                            COMPASS      Condo      69000
# 4  Sotheby's International Realty - East Side Man...  Townhouse   55000000
#
#    BEDS       BATH  PROPERTYSQFT  \
# 0     2   2.000000        1400.0
# 1     7  10.000000       17545.0
# 2     4   2.000000        2015.0
# 3     3   1.000000         445.0
# 4     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
df["BATH"] = df["BATH"].astype(int)
df
# Out:
#                                             BROKERTITLE       TYPE      PRICE  \
# 0                       Douglas Elliman  -111 Fifth Ave      Condo     315000
# 1                                               Serhant      Condo  195000000
# 2                                            Sowae Corp      House     260000
# 3                                               COMPASS      Condo      69000
# 4     Sotheby's International Realty - East Side Man...  Townhouse   55000000
# ...                                                 ...        ...        ...
# 4796                                            COMPASS      Co-op     599000
# 4797                                Mjr Real Estate Llc      Co-op     245000
# 4798                  Douglas Elliman - 575 Madison Ave      Co-op    1275000
# 4799                        E Realty International Corp      Condo     598125
# 4800                             Nyc Realty Brokers Llc      Co-op     349000
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['TYPE'] = le.fit_transform(df['TYPE'])
df['ADMINISTRATIVE_AREA_LEVEL_2'] = le.fit_transform(df['ADMINISTRATIVE_AREA_LEVEL_2'])
df['LOCALITY'] = le.fit_transform(df['LOCALITY'])
df['SUBLOCALITY'] = le.fit_transform(df['SUBLOCALITY'])
df['STREET_NAME'] = le.fit_transform(df['STREET_NAME'])
df.head()
# Out:
#                                          BROKERTITLE  TYPE      PRICE  BEDS  \
# 0                    Douglas Elliman  -111 Fifth Ave     2     315000     2
# 1                                            Serhant     2  195000000     7
# 2                                         Sowae Corp     7     260000     4
# 3                                            COMPASS     2      69000     3
# 4  Sotheby's International Realty - East Side Man...    12   55000000     7
#
#    BATH  PROPERTYSQFT                                            ADDRESS  \
# 0     2        1400.0                               2 E 55th St Unit 803
# 1    10       17545.0  Central Park Tower Penthouse-217 W 57th New Yo...
# 2     2        2015.0                                   620 Sinclair Ave
# 3     1         445.0                            2 E 55th St Unit 908W33
# 4     2       14175.0                                        5 E 64th St
#
# ...

# %%
target = df["PRICE"]
features = df.drop(["PRICE","BROKERTITLE","ADDRESS","STATE","MAIN_ADDRESS","LONG_NAME","FORMATTED_ADDRESS","LATITUDE","LONGITUDE"], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
RFC = RandomForestRegressor()

# %%
RFC.fit(X_train,y_train)
predictions = RFC.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 RFC.fit(X_train,y_train)
#       2 predictions = RFC.predict(X_test)
# ----> 3 accuracy = accuracy_score(y_test, predictions)
#       4 print(f"Accuracy: {accuracy}")
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...
